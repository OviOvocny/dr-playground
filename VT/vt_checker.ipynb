# %%
#to be able to run your async code in the notebook
import nest_asyncio
import sys
nest_asyncio.apply()
import os
import subprocess
from typing import List, Tuple, Optional
import pyarrow.parquet as pq
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm  # tqdm.notebook for Jupyter notebook
from dotenv import load_dotenv
from PyPDF2 import PdfMerger
import math
import requests
import datetime
from matplotlib.backends.backend_pdf import PdfPages
from requests.exceptions import RequestException

# %%
mode = 'malign'  # You can change this to 'benign' to read from the benign dataset
input_mode = 'txt'  # You can change this to 'txt'
# Maximum of api calls for VirusTotal, current academic api is 20k per day
batch_size = 20000

# %% [markdown]
# ## DomainAnalyzer
# **Objective**: Define the `DomainAnalyzer` class that will handle domain analysis tasks.
#
# - **Functions Included**:
#     - `__init__`: Initializes the `DomainAnalyzer` with a VirusTotal API key loaded from an environment variable.
#     - `__enter__` and `__exit__`: Context management methods to handle the setup and cleanup of the client.
#     - `initialize_client`: Load API key and initialize the vt.Client.
#     - `check_domain`: Fetch information for a specific domain.
#     - `get_verdict`: Determine the verdict of the analysis based on the domain's analysis stats.
#     - `is_domain_live`: Check if a domain is live by calling a bash script.
#     - `extract_domain_data`: Extract necessary data from the domain result.
#     - `load_previous_data`: Load previously processed domain data from a CSV file.
#     - `save_data`: Save the DataFrame containing domain data to a CSV file.
#     - `generate_report`: Generate a report based on the DataFrame and save it as a PDF.
#     - `process_selected_domains`: Process the domains based on the mode ('malign' or 'benign') in batches.

# %%
class DomainAnalyzer:
    def __init__(self):
        self.api_key = self._load_api_key()
        self.headers = self._create_headers()

    @staticmethod
    def _load_api_key():
        load_dotenv()
        api_key = os.getenv('VT_API_KEY')
        if api_key is None:
            raise ValueError("API key is not set. Please set the VT_API_KEY environment variable.")
        return api_key

    def _create_headers(self):
        return {"x-apikey": self.api_key, "Accept": "application/json"}

    def __enter__(self):
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        pass
    
    def check_domain(self, domain: str) -> Optional[dict]:
        url = f"https://www.virustotal.com/api/v3/domains/{domain}"
        response = requests.get(url, headers=self.headers)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:
            print(f"Quota exceeded when attempting to fetch information for domain {domain}.")
            return "Quota Exceeded"
        else:
            print(f"Error: Unable to fetch information for domain {domain}. {response.text}")
            return None

    def _determine_verdict(self, analysis_stats: dict) -> str:
        return "Malign" if analysis_stats.get('malicious', 0) > 0 or analysis_stats.get('suspicious', 0) > 1 else "Benign" 
        
    def _is_domain_live(self, domain: str) -> str:
        try:
            result = subprocess.run(['./livetest.sh', domain], capture_output=True, text=True)
            return "Alive" if result.stdout.strip() == '1' else "Dead"
        except Exception as e:
            print(f"Error: Unable to check if domain {domain} is live. {e}")
            return "Unknown"
        
    def _format_timestamp(self, timestamp):
        return datetime.datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')

    def extract_domain_data(self, domain: str, result: dict) -> Optional[Tuple]:
        try:
            attributes = result['data']['attributes']
            # print(attributes)
            analysis_stats = attributes['last_analysis_stats']
            verdict = self._determine_verdict(analysis_stats)
            detection_ratio = f"{analysis_stats['malicious']}/{analysis_stats['malicious'] + analysis_stats['harmless']}"

            last_analysis_date = attributes.get('last_analysis_date', attributes.get('last_submission_date', 0))
            formatted_timestamp = self._format_timestamp(last_analysis_date) if last_analysis_date else 'N/A'

            domain_status = self._is_domain_live(domain)
            #print all stats:
            print(f"Domain: {domain}, Verdict: {verdict}, Detection Ratio: {detection_ratio}, Timestamp: {formatted_timestamp}, Harmless: {analysis_stats.get('harmless', 0)}, Malicious: {analysis_stats.get('malicious', 0)}, Suspicious: {analysis_stats.get('suspicious', 0)}, Live Status: {domain_status}")
            return (domain, verdict, detection_ratio, formatted_timestamp, analysis_stats.get('harmless', 0), analysis_stats.get('malicious', 0), analysis_stats.get('suspicious', 0), domain_status)
        except KeyError:
            print(f"Error: Could not extract analysis stats for domain {domain}")
            return None

    def load_previous_data(self, mode: str) -> pd.DataFrame:
        """
        Load previously processed domain data from a CSV file or text file.
        """

        previous_data_filename = f'previous_data_{mode}.csv'
        if os.path.exists(previous_data_filename):
            return pd.read_csv(previous_data_filename)
        else:
            columns = ["Domain", "Verdict", "Detection Ratio", "Detection Timestamp", "Harmless", "Malicious", "Suspicious", "Live Status"]
            return pd.DataFrame(columns=columns)

    def save_data(self, df: pd.DataFrame, mode) -> None:
        """
        Save the DataFrame containing domain data to a CSV file or text file.
        """

        df.to_csv(f'previous_data_{mode}.csv', index=False)

    def save_checkpoint(self, data, processed_domains, mode, total_processed):
        columns = ["Domain", "Verdict", "Detection Ratio", "Detection Timestamp", "Harmless", "Malicious", "Suspicious", "Live Status"]
        new_df = pd.DataFrame(data, columns=columns)

        # Load the previous data
        old_df = self.load_previous_data(mode)
        
        # Merge the old and new data, removing duplicates
        merged_df = pd.concat([old_df, new_df]).drop_duplicates(subset=['Domain']).reset_index(drop=True)
        self.save_data(merged_df, mode)

        # Overwrite the processed domains file with the updated list
        processed_domains_file = f"processed_domains_{mode}.txt"
        with open(processed_domains_file, 'w') as file:
            file.write('\n'.join(processed_domains))
        print(f"Checkpoint saved to previous_data_{mode}.csv and processed_domains_{mode}.txt")

    def generate_report(self, df: pd.DataFrame, output_filename: str, rows_per_page: int = 500) -> None:
        """
        Generate a report based on the DataFrame and save it as a PDF, including a summary at the end.
        """
        num_pages = math.ceil(len(df) / rows_per_page)

        benign_count = len(df[df['Verdict'] == 'Benign'])
        malign_count = len(df[df['Verdict'] == 'Malign'])
        total_count = len(df)

        with PdfPages(output_filename) as pdf_pages:
            for page in range(num_pages):
                start_row = page * rows_per_page
                end_row = start_row + rows_per_page
                page_df = df[start_row:end_row]

                # If it's the last page, add the summary rows
                if page == num_pages - 1:
                    page_df = page_df.fillna('-')
                    summary_df = pd.DataFrame({
                        "Domain": ["", ""],
                        "Verdict": ["Benign count", "Malign count"],
                        "Detection Ratio": [f"{benign_count}/{total_count}", f"{malign_count}/{total_count}"],
                        # Other columns can be filled with appropriate data or left empty
                    }).reindex(columns=page_df.columns).fillna('-')

                    page_df = pd.concat([page_df, summary_df], ignore_index=True)

                fig_height = max(len(page_df) * 0.01, 4.8)  # Ensure a minimum height
                fig, ax = plt.subplots(figsize=(11, fig_height))
                
                ax.axis('off')  # Hide axes
                plt.tight_layout(pad=0.2)

                colWidths = [
                    max(page_df["Domain"].apply(lambda x: len(x) if x is not None else 0).max() * 0.25, 0.1) * 0.02 if column == "Domain" 
                    else 0.15 if column == "Detection Timestamp" 
                    else 0.1 for column in page_df.columns
                ]

                tab = pd.plotting.table(ax, page_df, loc='upper center', colWidths=colWidths, cellLoc='center', rowLoc='center')
                tab.auto_set_font_size(False)
                tab.set_fontsize(8)
                tab.scale(1.2, 1.2)

                for key, cell in tab.get_celld().items():
                    if key[0] == 0 or key[1] == -1:
                        cell.get_text().set_weight('bold')
                    if 'Verdict' in page_df.columns:
                        if cell.get_text().get_text() == 'Malign':
                            cell.set_text_props(color='red')
                        elif cell.get_text().get_text() == 'Benign':
                            cell.set_text_props(color='green')
                    if 'Live Status' in page_df.columns:
                        if cell.get_text().get_text() == 'Live':
                            cell.set_text_props(color='green')
                        elif cell.get_text().get_text() == 'Dead':
                            cell.set_text_props(color='red')
                    if key[1] == -1:
                        cell.set_visible(False)
                    if page == num_pages - 1 and key[0] >= len(page_df) - 1:  # This line is changed
                        cell.set_text_props(weight='bold')
                        cell.get_text().set_color('black')
                        cell.set_facecolor('lightgrey')

                pdf_pages.savefig(fig, bbox_inches='tight')
                plt.close(fig)

    def process_selected_domains(self, input_mode: str, mode: str, batch_size) -> pd.DataFrame:
        """
        Process the domains based on the mode ('malign' or 'benign') in batches.
        """
        if input_mode not in ['parquet', 'txt']:
            print(f"Invalid input mode '{input_mode}'. Please use 'parquet' or 'txt'.")
            return pd.DataFrame()

        paths = {
            'parquet': {
                'malign': '../floor/malware.parquet',
                'benign': '../floor/benign_cesnet_union_2307.parquet'
            },
            'txt': {
                'malign': '../floor/malware_Norbi.txt',
                'benign': '../floor/CESNET_domains_530K.txt',
            }
        }
        # Read the selected Parquet file or text file and get the domain names
        if input_mode == 'parquet':
            table = pq.read_table(paths[input_mode][mode])
            domain_names = table.column('domain_name').to_pandas()
        else:  # input_mode == 'txt'
            #open the file and read the lines
            with open(paths[input_mode][mode], 'r') as file:
                domain_names = file.read().splitlines()

        # Load the processed domains
        processed_domains_file = f"processed_domains_{mode}.txt"

        
        if os.path.exists(processed_domains_file):
            with open(processed_domains_file, 'r') as file:
                processed_domains = file.read().splitlines()
        else:
            processed_domains = []

        data = []
        processed_in_this_run = 0
        total_processed = len(processed_domains)
        
        progress_bar = tqdm(total=len(domain_names), desc='Processing domains', unit='domain')
        for domain in domain_names:
            progress_bar.update(1)
            if domain not in processed_domains:
                try:
                    result = self.check_domain(domain)
                    if result == "Quota Exceeded":
                        # Quota exceeded, generate report and exit
                        print("Quota is exceeded, generating report...")
                        df = self.load_previous_data(mode)
                        df.sort_values(by=['Verdict', 'Live Status'], ascending=[False, False], inplace=True)
                        df.dropna(inplace=True)
                        progress_bar.close()
                        return df
                    elif result:
                        # Extract data if domain check was successful
                        data.append(self.extract_domain_data(domain, result))
                        processed_domains.append(domain)  # Assuming processed_domains is a set
                        processed_in_this_run += 1
                        total_processed += 1
                        
                        # Checkpoint save logic remains unchanged
                        if total_processed % 1000 == 0:
                            self.save_checkpoint(data, processed_domains, mode, total_processed)
                except Exception as e:
                    print(f"Unexpected error occurred: {e}")
                if processed_in_this_run >= batch_size:
                    break
        progress_bar.close()

        self.save_checkpoint(data, processed_domains, mode, total_processed)
        columns = ["Domain", "Verdict", "Detection Ratio", "Detection Timestamp", "Harmless", "Malicious", "Suspicious", "Live Status"]
        
        # Create a DataFrame from the newly processed data
        new_df = pd.DataFrame(data, columns=columns)
        old_df = self.load_previous_data(mode)

        if old_df.empty:
            merged_df = new_df
        elif new_df.empty:
            merged_df = old_df
        else:
            merged_df = pd.concat([old_df, new_df]).drop_duplicates(subset=['Domain']).reset_index(drop=True)
        
        merged_df.sort_values(by=['Verdict', 'Live Status'], ascending=[False, False], inplace=True)
        merged_df.dropna(inplace=True)
        # Save the merged data
        self.save_data(merged_df, mode)
        #print how many domains were processed in total, also include percentages
        print(f"Total number of domains processed: {len(merged_df)} out of {len(domain_names)} ({len(merged_df)/len(domain_names)*100:.2f}%)")
        return merged_df

# %% [markdown]
# **Objective**: Utilize the `DomainAnalyzer` class to process and analyze domains.
#
# - **Steps**:
#     1. Instantiate the `DomainAnalyzer` class.
#     2. Use the `process_selected_domains` method to process domains based on the specified mode and batch size.
#     3. If domains are processed successfully, generate and save a report using the `generate_report` method.
#
# **Note**: Ensure that you have the necessary files, API keys, and configurations before running this cell.

# %%
# Example usage in a Jupyter notebook cell:
with DomainAnalyzer() as analyzer:  # Using the analyzer as a context manager
    df = analyzer.process_selected_domains(input_mode, mode, batch_size)  # This should generate your DataFrame df
    if df is not None and not df.empty:  # Ensure that df is not empty or None
        analyzer.generate_report(df, f'{mode}_VT_check.pdf')  # This will use the DataFrame df
        print(f'Report saved as {mode}_VT_check.pdf')
    else:
        print(f"No domains processed for mode '{mode}'. No report generated.")
# Out:
# Processing domains:   0%|          | 0/44333 [00:00<?, ?domain/s]
# {'last_dns_records': [{'type': 'NS', 'value': 'kh1.7hostir.com', 'ttl': 21600}, {'type': 'NS', 'value': 'kh2.7hostir.com', 'ttl': 21600}, {'priority': 0, 'type': 'MX', 'value': 'shopsabz.com', 'ttl': 14400}, {'type': 'TXT', 'value': 'v=spf1 ip4:185.165.31.55 +a +mx +ip4:185.88.177.189 ~all', 'ttl': 14400}, {'rname': 'monitor.7host.cloud', 'retry': 1800, 'value': 'kh1.7hostir.com', 'minimum': 86400, 'refresh': 3600, 'expire': 1209600, 'ttl': 21600, 'serial': 2023092700, 'type': 'SOA'}], 'jarm': '29d29d00029d29d00042d43d00041d598ac0c1012db967bb1ad0ff2491b3ae', 'whois': 'Admin City: REDACTED FOR PRIVACY\nAdmin Country: REDACTED FOR PRIVACY\nAdmin Email: 4babf6fcc6f7794as@domain-contact.org\nAdmin Organization: REDACTED FOR PRIVACY\nAdmin Postal Code: REDACTED FOR PRIVACY\nAdmin State/Province: REDACTED FOR PRIVACY\nBilling City: REDACTED FOR PRIVACY\nBilling Country: REDACTED FOR PRIVACY\nBilling Email: 4babf6fcc6f7794as@domain-contact.org\nBilling Organization: REDACTED FOR PRIVACY\nBilling Postal Code: REDACTED FOR PRIVACY\nBilling State/Province: REDACTED FOR PRIVACY\nCreation Date: 2016-04-23T09:16:00Z\nDNSSEC: unsigned\nDomain Name: SHOPSABZ.COM\nDomain Name: shopsabz.com\nDomain Status: ok https://icann.org/epp#ok\nName Server: KH1.7HOSTIR.COM\nName Server: KH2.7HOSTIR.COM\nName Server: kh1.7hostir.com\nName Server: kh2.7hostir.com\nRegistrant City: 1f8f4166599d23ee\nRegistrant Country: TR\nRegistrant Email: 4babf6fcc6f7794as@domain-contact.org\nRegistrant Fax Ext: 1f8f4166599d23ee\nRegistrant Fax: 1f8f4166599d23ee\nRegistrant Name: 1f8f4166599d23ee\nRegistrant Organization: 1f8f4166599d23ee\nRegistrant Phone Ext: 1f8f4166599d23ee\nRegistrant Phone: 1f8f4166599d23ee\nRegistrant Postal Code: 1f8f4166599d23ee\nRegistrant State/Province: 817714c52982adcf\nRegistrant Street: 1f8f4166599d23ee\nRegistrar Abuse Contact Email: abuse@key-systems.net\nRegistrar Abuse Contact Email: abusereport@key-systems.net\nRegistrar Abuse Contact Phone: +49.68949396850\nRegistrar IANA ID: 269\nRegistrar Registration Expiration Date: 2024-04-23T09:16:00Z\nRegistrar URL: http://www.key-systems.net\nRegistrar WHOIS Server: whois.rrpproxy.net\nRegistrar: Key-Systems GmbH\nRegistry Admin ID: REDACTED FOR PRIVACY\nRegistry Billing ID: REDACTED FOR PRIVACY\nRegistry Domain ID: 2023563603_DOMAIN_COM-VRSN\nRegistry Expiry Date: 2024-04-23T09:16:00Z\nRegistry Registrant ID: REDACTED FOR PRIVACY\nRegistry Tech ID: REDACTED FOR PRIVACY\nTech City: REDACTED FOR PRIVACY\nTech Country: REDACTED FOR PRIVACY\nTech Email: 4babf6fcc6f7794as@domain-contact.org\nTech Organization: REDACTED FOR PRIVACY\nTech Postal Code: REDACTED FOR PRIVACY\nTech State/Province: REDACTED FOR PRIVACY\nUpdated Date: 2023-02-22T09:18:31Z', 'last_https_certificate_date': 1705406604, 'tags': [], 'popularity_ranks': {'Statvoo': {'timestamp': 1674838687, 'rank': 324247}, 'Alexa': {'timestamp': 1674838686, 'rank': 324247}}, 'last_analysis_date': 1705406594, 'last_dns_records_date': 1705406604, 'last_analysis_stats': {'harmless': 64, 'malicious': 4, 'suspicious': 2, 'undetected': 19, 'timeout': 0}, 'creation_date': 1461402960, 'whois_date': 1705406604, 'reputation': 0, 'registrar': 'Key-Systems GmbH', 'last_analysis_results': {'Bkav': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Bkav'}, 'CMC Threat Intelligence': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CMC Threat Intelligence'}, 'Snort IP sample list': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Snort IP sample list'}, '0xSI_f33d': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': '0xSI_f33d'}, 'ViriBack': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'ViriBack'}, 'MalwareURL': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'MalwareURL'}, 'PhishLabs': {'category': 'undetected', 'result': 'unrated', 'method': 'bl ...
# Domain: shopsabz.com, Verdict: Malign, Detection Ratio: 4/68, Timestamp: 2024-01-16 12:03:14, Harmless: 64, Malicious: 4, Suspicious: 2, Live Status: Alive
# {'last_dns_records': [{'type': 'NS', 'value': 'ns4.theonlygoodman.com', 'ttl': 300}, {'type': 'NS', 'value': 'ns6.theonlygoodman.com', 'ttl': 300}, {'type': 'TXT', 'value': 'v=spf1 include:_incspfcheck.mailspike.net ?all', 'ttl': 300}, {'priority': 10, 'type': 'MX', 'value': 'mx2.theonlygoodman.com', 'ttl': 300}, {'type': 'NS', 'value': 'ns1.theonlygoodman.com', 'ttl': 300}, {'type': 'NS', 'value': 'ns3.theonlygoodman.com', 'ttl': 300}, {'type': 'NS', 'value': 'ns2.theonlygoodman.com', 'ttl': 300}, {'rname': 'hostmaster.theonlygoodman.com', 'retry': 2048, 'refresh': 16384, 'minimum': 2560, 'value': 'ns8.theonlygoodman.com', 'expire': 1048576, 'ttl': 2560, 'serial': 1705325235, 'type': 'SOA'}, {'type': 'NS', 'value': 'ns8.theonlygoodman.com', 'ttl': 300}, {'type': 'NS', 'value': 'ns5.theonlygoodman.com', 'ttl': 300}, {'priority': 10, 'type': 'MX', 'value': 'mx1.theonlygoodman.com', 'ttl': 300}, {'type': 'A', 'value': '104.198.2.251', 'ttl': 300}, {'type': 'NS', 'value': 'ns7.theonlygoodman.com', 'ttl': 300}], 'jarm': '2ad2ad16d2ad2ad00042d42d000000a5308aa908d3edc2392a602b7adac57a', 'whois': 'Admin City: San Mateo\nAdmin Country: US\nAdmin Organization: Super Privacy Service LTD c/o Dynadot\nAdmin Postal Code: 94401\nAdmin State/Province: California\nCreation Date: 2021-11-20T11:00:18.0Z\nCreation Date: 2021-11-20T11:00:18Z\nDNSSEC: unsigned\nDomain Name: THEONLYGOODMAN.COM\nDomain Status: clientTransferProhibited https://icann.org/epp#clientTransferProhibited\nName Server: NS1.THEONLYGOODMAN.COM\nName Server: NS2.THEONLYGOODMAN.COM\nName Server: NS3.THEONLYGOODMAN.COM\nName Server: NS4.THEONLYGOODMAN.COM\nName Server: NS5.THEONLYGOODMAN.COM\nName Server: NS6.THEONLYGOODMAN.COM\nName Server: NS7.THEONLYGOODMAN.COM\nName Server: NS8.THEONLYGOODMAN.COM\nName Server: ns1.theonlygoodman.com\nName Server: ns2.theonlygoodman.com\nName Server: ns3.theonlygoodman.com\nName Server: ns4.theonlygoodman.com\nName Server: ns5.theonlygoodman.com\nName Server: ns6.theonlygoodman.com\nName Server: ns7.theonlygoodman.com\nName Server: ns8.theonlygoodman.com\nRegistrant City: 3715f4e2b12e17cb\nRegistrant Country: US\nRegistrant Email: dd87723767e48a47s@\nRegistrant Name: 1f8f4166599d23ee\nRegistrant Organization: 473daf17453d83cd\nRegistrant Phone: dd8b86e7cf387e10\nRegistrant Postal Code: ae51fcfbe03bd2c4\nRegistrant State/Province: 77ab92f1911d7c5f\nRegistrant Street: 3432650ec337c945\nRegistrant Street: 8a188706046fdffa\nRegistrar Abuse Contact Email: abuse@dynadot.com\nRegistrar Abuse Contact Phone: +1.6502620100\nRegistrar Abuse Contact Phone: +16502620100\nRegistrar IANA ID: 472\nRegistrar Registration Expiration Date: 2024-11-20T11:00:18.0Z\nRegistrar URL: http://www.dynadot.com\nRegistrar WHOIS Server: whois.dynadot.com\nRegistrar: DYNADOT LLC\nRegistrar: Dynadot Inc\nRegistry Domain ID: 2656300187_DOMAIN_COM-VRSN\nRegistry Expiry Date: 2024-11-20T11:00:18Z\nTech City: San Mateo\nTech Country: US\nTech Organization: Super Privacy Service LTD c/o Dynadot\nTech Postal Code: 94401\nTech State/Province: California\nUpdated Date: 2023-10-25T09:05:55.0Z\nUpdated Date: 2023-10-25T09:05:55Z', 'last_https_certificate_date': 1705325317, 'tags': [], 'popularity_ranks': {'Cisco Umbrella': {'timestamp': 1686329892, 'rank': 823418}}, 'last_analysis_date': 1705325312, 'last_dns_records_date': 1705325317, 'last_analysis_stats': {'harmless': 53, 'malicious': 17, 'suspicious': 0, 'undetected': 19, 'timeout': 0}, 'creation_date': 1637406018, 'whois_date': 1705308656, 'reputation': 0, 'registrar': 'DYNADOT LLC', 'last_analysis_results': {'Bkav': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Bkav'}, 'CMC Threat Intelligence': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CMC Threat Intelligence'}, 'Snort IP sample list': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Snort IP sample list'}, '0xSI_f33d': {'category': 'undetected', 'result': 'unrate ...
# Domain: theonlygoodman.com, Verdict: Malign, Detection Ratio: 17/70, Timestamp: 2024-01-15 13:28:32, Harmless: 53, Malicious: 17, Suspicious: 0, Live Status: Dead
# {'last_dns_records': [{'type': 'A', 'value': '222.255.167.54', 'ttl': 360}, {'type': 'NS', 'value': 'ns2.vinabits.net', 'ttl': 360}, {'type': 'NS', 'value': 'ns3.vinabits.net', 'ttl': 360}, {'type': 'TXT', 'value': 'v=spf1 a mx:tienphongmientrung.com ip4:222.255.167.35 ?all', 'ttl': 360}, {'priority': 10, 'type': 'MX', 'value': 'antispam.tienphongmientrung.com', 'ttl': 360}, {'type': 'NS', 'value': 'ns1.vinabits.net', 'ttl': 360}, {'rname': 'hostmaster.tienphongmientrung.com', 'retry': 3600, 'refresh': 14400, 'minimum': 86400, 'value': 'ns1.vinabits.net', 'expire': 1209600, 'ttl': 3600, 'serial': 2022081520, 'type': 'SOA'}], 'jarm': '15d3fd16d29d29d00042d43d00000071784fa9f8305ba9220d0a7894b6ff2c', 'whois': 'Admin City: Da Nang\nAdmin Country: VN\nAdmin Email: 2b2b413448e02bdas@gmail.com\nAdmin Postal Code: 550000\nCreation Date: 2017-04-13 00:00:00\nCreation Date: 2017-04-13T01:51:53Z\nDNSSEC: unsigned\nDomain Name: TIENPHONGMIENTRUNG.COM\nDomain Name: tienphongmientrung.com\nDomain Status: clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited\nDomain Status: clientTransferProhibited https://icann.org/epp#clientTransferProhibited\nName Server: NS1.VINABITS.NET\nName Server: NS2.VINABITS.NET\nName Server: NS3.VINABITS.NET\nName Server: ns1.vinabits.net\nName Server: ns2.vinabits.net\nName Server: ns3.vinabits.netDNSSEC:Unsigned\nRegistrant City: 4e15a03beefdb190\nRegistrant Country: VN\nRegistrant Email: 2b2b413448e02bdas@gmail.com\nRegistrant Fax: 3432650ec337c945\nRegistrant Name: 8320bba25af7ea5c\nRegistrant Organization: 3432650ec337c945\nRegistrant Phone Ext: 3432650ec337c945\nRegistrant Phone: a79048a54a2b7238\nRegistrant Postal Code: 2b421a5f6a47538b\nRegistrant State/Province: 3432650ec337c945\nRegistrant Street: b9eaf2a649247579\nRegistrar Abuse Contact Email: abuse@pavietnam.vn\nRegistrar Abuse Contact Phone: +84.2873019954\nRegistrar IANA ID: 1649\nRegistrar Registration Expiration Date: 2024-04-13 00:00:00\nRegistrar URL: http://www.pavietnam.vn\nRegistrar WHOIS Server: whois.pavietnam.vn\nRegistrar: P.A. Viet Nam Company Limited\nRegistry Admin ID: Not available from Registry\nRegistry Domain ID: 2113777001_DOMAIN_COM-VRSN\nRegistry Expiry Date: 2024-04-13T01:51:53Z\nRegistry Registrant ID: Not available from Registry\nRegistry Tech ID: Not available from Registry\nTech City: Da Nang\nTech Country: VN\nTech Email: 2b2b413448e02bdas@gmail.com\nTech Postal Code: 550000\nUpdated Date: 2023-04-13\nUpdated Date: 2023-04-13T03:28:03Z', 'last_https_certificate_date': 1704110323, 'tags': ['self-signed'], 'popularity_ranks': {'Statvoo': {'timestamp': 1669222688, 'rank': 481220}, 'Alexa': {'timestamp': 1669222687, 'rank': 481220}}, 'last_analysis_date': 1704110175, 'last_dns_records_date': 1704110323, 'last_analysis_stats': {'harmless': 62, 'malicious': 6, 'suspicious': 0, 'undetected': 21, 'timeout': 0}, 'creation_date': 1492048313, 'whois_date': 1704110323, 'reputation': 0, 'registrar': 'P.A. Viet Nam Company Limited', 'last_analysis_results': {'Bkav': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Bkav'}, 'CMC Threat Intelligence': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CMC Threat Intelligence'}, 'Snort IP sample list': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Snort IP sample list'}, '0xSI_f33d': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': '0xSI_f33d'}, 'ViriBack': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'ViriBack'}, 'MalwareURL': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'MalwareURL'}, 'PhishLabs': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'PhishLabs'}, 'K7AntiVirus': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'K7AntiVirus'}, 'CINS Army': {'category': 'harmless', 'resul ...
# Domain: tienphongmientrung.com, Verdict: Malign, Detection Ratio: 6/68, Timestamp: 2024-01-01 11:56:15, Harmless: 62, Malicious: 6, Suspicious: 0, Live Status: Alive
# {'last_dns_records': [{'type': 'A', 'value': '109.70.26.37', 'ttl': 599}, {'type': 'NS', 'value': 'ns1.expired.r01.ru', 'ttl': 3599}, {'type': 'TXT', 'value': 'b487eed96a113bdebfa27158a90a164c2b0c1ed6', 'ttl': 599}, {'type': 'A', 'value': '194.85.61.76', 'ttl': 599}, {'priority': 0, 'type': 'MX', 'value': 'nomail.nic.ru', 'ttl': 599}, {'type': 'NS', 'value': 'ns2.expired.r01.ru', 'ttl': 3599}, {'rname': 'hostmaster.r01.ru', 'retry': 7200, 'value': 'ns1.expired.r01.ru', 'minimum': 86400, 'refresh': 86400, 'expire': 604800, 'ttl': 3599, 'serial': 1578932125, 'type': 'SOA'}], 'whois': 'Last updated on 2021-02-09T16:36:30Z', 'last_https_certificate_date': 1575285894, 'tags': [], 'popularity_ranks': {'Cisco Umbrella': {'timestamp': 1655830694, 'rank': 987198}}, 'last_analysis_date': 1705406728, 'last_dns_records_date': 1578934175, 'last_analysis_stats': {'harmless': 60, 'malicious': 10, 'suspicious': 1, 'undetected': 18, 'timeout': 0}, 'whois_date': 1612888894, 'reputation': 0, 'last_analysis_results': {'Bkav': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Bkav'}, 'CMC Threat Intelligence': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CMC Threat Intelligence'}, 'Snort IP sample list': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Snort IP sample list'}, '0xSI_f33d': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': '0xSI_f33d'}, 'ViriBack': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'ViriBack'}, 'MalwareURL': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'MalwareURL'}, 'PhishLabs': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'PhishLabs'}, 'K7AntiVirus': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'K7AntiVirus'}, 'CINS Army': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CINS Army'}, 'Quttera': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Quttera'}, 'PrecisionSec': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'PrecisionSec'}, 'OpenPhish': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'OpenPhish'}, 'VX Vault': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'VX Vault'}, 'ArcSight Threat Intelligence': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'ArcSight Threat Intelligence'}, 'Scantitan': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Scantitan'}, 'AlienVault': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'AlienVault'}, 'Sophos': {'category': 'malicious', 'result': 'phishing', 'method': 'blacklist', 'engine_name': 'Sophos'}, 'Phishtank': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Phishtank'}, 'Cyan': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Cyan'}, 'Spam404': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Spam404'}, 'SecureBrain': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'SecureBrain'}, 'CRDF': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CRDF'}, 'Fortinet': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Fortinet'}, 'alphaMountain.ai': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'alphaMountain.ai'}, 'Lionic': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Lionic'}, 'Cyble': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Cyble'}, 'Seclookup': {'category': 'malicious', 'result': 'malicious', 'm ...
# Domain: psychologylibs.ru, Verdict: Malign, Detection Ratio: 10/70, Timestamp: 2024-01-16 12:05:28, Harmless: 60, Malicious: 10, Suspicious: 1, Live Status: Dead
# {'last_dns_records': [{'type': 'A', 'value': '15.197.142.173', 'ttl': 600}, {'type': 'TXT', 'value': 'NETORGFT7476231.onmicrosoft.com', 'ttl': 3600}, {'type': 'NS', 'value': 'ns21.domaincontrol.com', 'ttl': 3600}, {'rname': 'dns.jomax.net', 'retry': 7200, 'value': 'ns21.domaincontrol.com', 'minimum': 600, 'refresh': 28800, 'expire': 604800, 'ttl': 3600, 'serial': 2021101500, 'type': 'SOA'}, {'type': 'A', 'value': '3.33.152.147', 'ttl': 600}, {'type': 'NS', 'value': 'ns22.domaincontrol.com', 'ttl': 3600}, {'type': 'TXT', 'value': 'v=spf1 include:spf.protection.outlook.com -all', 'ttl': 3600}, {'type': 'TXT', 'value': 'NETORGFT5671557.onmicrosoft.com', 'ttl': 3600}, {'priority': 0, 'type': 'MX', 'value': 'almashghal-com.mail.protection.outlook.com', 'ttl': 3600}], 'jarm': '2ad2ad0002ad2ad22c2ad2ad2ad2adcb923bdf24d76ffa93e37532e1a9239b', 'whois': 'Creation Date: 2018-01-30T07:15:18Z\nDNSSEC: unsigned\nDomain Name: ALMASHGHAL.COM\nDomain Status: clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited\nDomain Status: clientRenewProhibited https://icann.org/epp#clientRenewProhibited\nDomain Status: clientTransferProhibited https://icann.org/epp#clientTransferProhibited\nDomain Status: clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited\nName Server: NS21.DOMAINCONTROL.COM\nName Server: NS22.DOMAINCONTROL.COM\nRegistrar Abuse Contact Email: abuse@godaddy.com\nRegistrar Abuse Contact Phone: 480-624-2505\nRegistrar IANA ID: 146\nRegistrar URL: http://www.godaddy.com\nRegistrar WHOIS Server: whois.godaddy.com\nRegistrar: GoDaddy.com, LLC\nRegistry Domain ID: 2220719178_DOMAIN_COM-VRSN\nRegistry Expiry Date: 2024-01-30T07:15:18Z\nUpdated Date: 2023-01-31T09:56:04Z', 'last_https_certificate_date': 1633795002, 'tags': [], 'popularity_ranks': {'Statvoo': {'timestamp': 1590593765, 'rank': 264541}}, 'last_analysis_date': 1705406729, 'last_dns_records_date': 1705406779, 'last_analysis_stats': {'harmless': 58, 'malicious': 11, 'suspicious': 1, 'undetected': 19, 'timeout': 0}, 'creation_date': 1517296518, 'whois_date': 1705406779, 'reputation': 0, 'registrar': 'GoDaddy.com, LLC', 'last_analysis_results': {'Bkav': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'Bkav'}, 'CMC Threat Intelligence': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CMC Threat Intelligence'}, 'Snort IP sample list': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Snort IP sample list'}, '0xSI_f33d': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': '0xSI_f33d'}, 'ViriBack': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'ViriBack'}, 'MalwareURL': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'MalwareURL'}, 'PhishLabs': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'PhishLabs'}, 'K7AntiVirus': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'K7AntiVirus'}, 'CINS Army': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'CINS Army'}, 'Quttera': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Quttera'}, 'PrecisionSec': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'PrecisionSec'}, 'OpenPhish': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'OpenPhish'}, 'VX Vault': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'VX Vault'}, 'ArcSight Threat Intelligence': {'category': 'undetected', 'result': 'unrated', 'method': 'blacklist', 'engine_name': 'ArcSight Threat Intelligence'}, 'Scantitan': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'Scantitan'}, 'AlienVault': {'category': 'harmless', 'result': 'clean', 'method': 'blacklist', 'engine_name': 'AlienVault ...
# Domain: almashghal.com, Verdict: Malign, Detection Ratio: 11/69, Timestamp: 2024-01-16 12:05:29, Harmless: 58, Malicious: 11, Suspicious: 1, Live Status: Alive
# Checkpoint saved to previous_data_malign.csv and processed_domains_malign.txt
# Total number of domains processed: 5 out of 44333 (0.01%)
# Report saved as malign_VT_check.pdf
