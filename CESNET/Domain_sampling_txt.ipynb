# %%
# BUILD_LIB=1 pip3 install ssdeep

import pandas as pd
import numpy as np
import tldextract

df = pd.read_csv('domains.txt', sep=' ', header=0, names=['domain'])

# %%
df['extracted'] = df['domain'].apply(lambda x: tldextract.extract(x))

df['suffix'] = df['extracted'].apply(lambda x: x.registered_domain)
df['suffix'].replace('', np.nan, inplace=True)
df.dropna(subset=['suffix'], inplace=True)

df['tld'] = df['extracted'].apply(lambda x: x.suffix)
df.drop(columns=['extracted'], inplace=True)

df.head(20)
# Out:
#                                                domain          suffix  tld
# 0                            0-courier.push.apple.com       apple.com  com
# 1                    0-courier.sandbox.push.apple.com       apple.com  com
# 2                           0-courier2.push.apple.com       apple.com  com
# 3   0-eu-west-1-awesomeads-166321764.eu-west-1.elb...   amazonaws.com  com
# 4                   0-gravatar-com.cdn.ampproject.org  ampproject.org  org
# 5                                    0-hubs.iosdm.net       iosdm.net  net
# 6   0-i2--prod-birminghammail-co-uk-0.cdn.ampproje...  ampproject.org  org
# 7   0-i2--prod-chroniclelive-co-uk-0.cdn.ampprojec...  ampproject.org  org
# 8   0-i2--prod-dailyrecord-co-uk-0.cdn.ampproject.org  ampproject.org  org
# 9     0-i2--prod-dailystar-co-uk-0.cdn.ampproject.org  ampproject.org  org
# 10    0-i2--prod-football-london-0.cdn.ampproject.org  ampproject.org  org
# 11     0-i2--prod-irishmirror-ie-0.cdn.ampproject.org  ampproject.org  org
# 12  0-i2--prod-liverpoolecho-co-uk-0.cdn.ampprojec...  ampproject.org  org
# 13  0-i2--prod-manchestereveningnews-co-uk-0.cdn.a...  ampproject.org  org
# 14       0-i2--prod-mirror-co-uk-0.cdn.ampproject.org  ampproject.org  org
# 15      0-i2--prod-mylondon-news-0.cdn.ampproject.org  ampproject.org  org
# 16  0-i2--prod-walesonline-co-uk-0.cdn.ampproject.org  ampproject.org  org
# 17       0-s2--prod-mirror-co-uk-0.cdn.ampproject.org  ampproject.org  org
# 18  0-s3--ap--southeast--1-amazonaws-com-0.cdn.amp...  ampproject.org  org
# 19  0-s3--eu--west--1-amazonaws-com-0.cdn.ampproje...  ampproject.org  org

# %%
len(df)
# Out:
# 51219

# %%
cutoff = 50
drop_ratio = 0.9
max_per_suffix=1000
final_take = 1000000

# %%
top_suffixes = df['suffix'].value_counts().nlargest(cutoff).index

for suf in top_suffixes:
    num_rows = len(df[df['suffix'] == suf])
    n_samples = int(num_rows * drop_ratio)
    # Only sample if there are enough rows to sample
    if n_samples > 0 and n_samples < num_rows:
        df.drop(df[df['suffix'] == suf].sample(n=n_samples).index, inplace=True)

# %%
len(df)
# Out:
# 37548

# %%
df['suffix'].value_counts().nlargest(10)
# Out:
# suffix
# casalemedia.com      371
# doubleclick.net      171
# akamai.net           129
# amazonaws.com         97
# sharepoint.com        70
# amazon.com            65
# akstat.io             64
# demdex.net            64
# zdusercontent.com     60
# webex.com             59
# Name: count, dtype: int64

# %%
def sample(group, maxr=100000):
    if len(group) > maxr:
        return group.sample(n=maxr, random_state=42)
    else:
        return group
    
grouped_df = df.groupby('suffix', group_keys=False).apply(sample, maxr=max_per_suffix).reset_index(drop=True)

grouped_df.head(50)
# Out:
#                                                domain  \
# 0                                    0-hubs.iosdm.net
# 1   0-i2--prod-birminghammail-co-uk-0.cdn.ampproje...
# 2   0-s3--ap--southeast--1-amazonaws-com-0.cdn.amp...
# 3                              0-ukwest1-pushp.svc.ms
# 4                               0.1.cn.akamaiedge.net
# 5                               0.1.cn.akamaitech.net
# 6                               0.academia-photos.com
# 7                                    0.allegroimg.com
# 8                               0.azuredatabricks.net
# 9                           0.bdrthermea.pool.ntp.org
# 10                         0.bridge.walletconnect.org
# 11                           0.camera.verkada-lan.com
# 12                      0.cdn.autotraderspecialty.com
# 13                               0.cl.ntp.edgeuno.com
# 14                               0.co.ntp.edgeuno.com
# 15                               0.co.uk.pool.ntp.org
# 16                              0.debian.pool.ntp.org
# 17                              0.digium.pool.ntp.org
# 18                                    0.dl.wsfiles.cz
# 19                                  0.ecom.attccc.com
# 20                                   0.freebasics.com
# 21                                     0.gravatar.com
# 22                                      0.ntp.nvts.co
# 23                             0.ntp.sky.shoretel.com
# 24                                       0.peerjs.com
# 25                            0.pioneerasphaltinc.com
# 26                                    0.s3.envato.com
# 27  0.samsung-internet.filter-list-downloads.eyeo.com
# 28  0.samsung-internet.filter-list-downloads.getad...
# 29                                               0.sb
# 30                                 0.sngdia.imtmp.net
# 31                                        0.soompi.io
# 32                          0.sourcefire.pool.ntp.org
# 33                                    0.ss.faisys.com
# 34                                0.t.keepitpumpin.io
# 35                                       0.threema.ch
# 36                             0.tiles.maps.proweb.hu
# 37                        0.time.chameleoncloud.co.uk
# 38                                          0.viki.io
# 39                               0.vizio.pool.ntp.org
# 40                             0.vornexl.pool.ntp.org
# 41                                      0.xxx-cdn.com
# 42                                00-hk.cloudxcdn.com
# 43                                00-jp.cloudxcdn.com
# 44                                00-us.cloudxcdn.com
# 45                            000000000000.phish.farm
# 46                                        00005555.cc
# 47                                    0001.arsmtp.com
# 48                                 000webhost.awex.io
# 49                                     000webhost.com
#
#                      suffix    tld
# 0                 iosdm.net    net
# 1            ampproject.org    org
# 2            ampproject.org    org
# 3                    svc.ms     ms
# 4            akamaiedge.net    net
# 5            akamaitech.net    net
# 6       academia-photos.com    com
# 7            allegroimg.com    com
# 8       azuredatabricks.net    net
# 9                   ntp.org    org
# 10        walletconnect.org    org
# 11          verkada-lan.com    com
# 12  autotraderspecialty.com    com
# 13              edgeuno.com    com
# 14              edgeuno.com    com
# 15                  ntp.org    org
# 16                  ntp.org    org
# 17                  ntp.org    org
# 18               wsfiles.cz     cz
# 19               attccc.com    com
# 20           freebasics.com    com
# 21             gravatar.com    com
# 22                  nvts.co     co
# 23             shoretel.com    com
# 24               peerjs.com    com
# 25    pioneerasphaltinc.com    com
# 26               envato.com    com
# 27                 eyeo.com    com
# 28           getadblock.com    com
# 29                     0.sb     sb
# 30                imtmp.net    net
# 31                soompi.io     io
# 32                  ntp.org    org
# 33               faisys.com    com
# 34          keepitpumpin.io     io
# 35               threema.ch     ch
# 36                proweb.hu     hu
# 37     chameleoncloud.co.uk  co.uk
# 38                  viki.io     io
# 39                  ntp.org    org
# 40                  ntp.org    org
# 41              xxx-cdn.com    com
# 42            cloudxcdn.com    com
# 43            cloudxcdn.com    com
# 44            cloudxcdn.com    com
# 45               phish.farm   farm
# 46              00005555.cc     cc
# 47               arsmtp.com    com
# 48                  awex.io     io
# 49           000webhost.com    com

# %%
# grouped_df['suffix'].value_counts().nlargest(20)

# %%
cnt = len(grouped_df)
cnt_str = round(cnt / 1000000, 1)

# %%
grouped_df.to_csv(f"domains_undersampled_{cutoff}_{max_per_suffix}_{cnt_str}M.txt", sep=' ')

# %%
# Assuming 'final_take' is the desired sample size.
# Ensure 'final_take' does not exceed the number of rows in 'grouped_df'.
final_take = min(final_take, len(grouped_df))

# Convert 'final_take' to a string representing millions for the filename.
final_take_str = str(round(final_take / 1_000_000, 1)) + 'M'

# Now 'final_take_str' can be used to create the filename.
sampled = grouped_df.sample(n=final_take, random_state=42)
sampled.to_csv(f"domains_undersampled_{cutoff}_{max_per_suffix}_{final_take_str}.txt", sep=' ')
